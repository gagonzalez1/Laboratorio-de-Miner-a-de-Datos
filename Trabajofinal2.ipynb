# %%
import sagemaker
from sagemaker.session import Session
from sagemaker import get_execution_role
from sagemaker import LinearLearner
import numpy as np
import pandas as pd

# Configuración inicial
role = get_execution_role()
bucket = 'trabajofinallaboratorio'
data_key = 'synthetic_customer_data.csv'
data_location = f's3://{bucket}/{data_key}'
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
# Cargar el dataset desde S3
df = pd.read_csv(data_location)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:279: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)

# %%
# !pip install --upgrade s3fs
# Out:
# Requirement already satisfied: s3fs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2024.10.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from s3fs) (2.15.2)
# Requirement already satisfied: fsspec==2024.10.0.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from s3fs) (2024.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from s3fs) (3.10.10)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.35.36)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.15.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.2.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)

# %%
# Preprocesamiento del dataset
# 1. Eliminar la columna 'customer_id'
df = df.drop(columns=['customer_id'])

# 2. Transformar la columna 'gender' en valores binarios
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)

# 3. Codificar la columna 'customer_segment' como numérica
df['customer_segment'] = df['customer_segment'].astype('category')
customer_segment_map = dict(enumerate(df['customer_segment'].cat.categories))
df['customer_segment'] = df['customer_segment'].cat.codes

# Imprimir el significado de los códigos asignados
print("Significado de los valores en 'customer_segment':")
for code, category in customer_segment_map.items():
    print(f"{code}: {category}")


# Dividir el dataset en conjuntos de entrenamiento y prueba
customer_data = df.values
num_train = int(customer_data.shape[0] * 0.80)  # 80% para entrenamiento

X_train = customer_data[:num_train, :-1]  # Todas las columnas excepto la última
y_train = customer_data[:num_train, -1]   # Última columna (target)

X_test = customer_data[num_train:, :-1]
y_test = customer_data[num_train:, -1]
# Out:
# Significado de los valores en 'customer_segment':
# 0: high_value
# 1: low_value
# 2: medium_value

# %%
# Crear la ruta en S3 para guardar el modelo
s3_prefix = 'customer-segmentation'
output_path = f's3://{bucket}/{s3_prefix}/'

# %%
# Instanciar el modelo Linear Learner
session = sagemaker.Session()
linear = LinearLearner(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.m4.xlarge',
    predictor_type='multiclass_classifier',  # Cambiado a clasificación multiclase
    num_classes=len(df['customer_segment'].unique()),  # Número de clases
    output_path=output_path,
    sagemaker_session=session,
    epochs=20
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# Convertir el conjunto de datos en RecordSet
training_recordset = linear.record_set(train=X_train.astype('float32'), labels=y_train.astype('float32'))

# %%
# Entrenar el modelo
linear.fit(training_recordset)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: linear-learner-2024-12-08-15-40-04-463
# 2024-12-08 15:40:05 Starting - Starting the training job...
# 2024-12-08 15:40:20 Starting - Preparing the instances for training...
# 2024-12-08 15:40:50 Downloading - Downloading input data...
# 2024-12-08 15:41:20 Downloading - Downloading the training image......
# 2024-12-08 15:42:31 Training - Training image download completed. Training in progress....
# 2024-12-08 15:43:02 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/08/2024 15:42:54 INFO 140469236098880] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/08/2024 15:42:54 INFO 140469236098880] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '20', 'feature_dim': '10', 'mini_batch_size': '800', 'num_classes': '3', 'predictor_type': 'multiclass_classifier'}
# [12/08/2024 15:42:54 INFO 140469236098880] Final configuration: {'mini_batch_size': '800', 'epochs': '20', 'feature_dim': '10', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '3', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [12/08/2024 15:42:57 WARNING 140469236098880] Loggers have already been setup.
# [12/08/2024 15:42:57 INFO 140469236098880] Final configuration: {'mini_batch_size': '800', 'epochs': '20', 'feature_dim': '10', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '3', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# [12/08/2024 15:42:57 WARNING 140469236098880] Loggers have already been setup.
# Process 7 is a worker.
# [12/08/2024 15:42:57 INFO 140469236098880] Using default worker.
# [12/08/2024 15:42:57 INFO 140469236098880] Checkpoint loading and saving are disabled.
# [2024-12-08 15:42:57.503] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes": 67200}
# [12/08/2024 15:42:57 INFO 140469236098880] Create Store: local
# [2024-12-08 15:42:57.516] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 12, "num_examples": 1, "num_bytes": 67200}
# [12/08/2024 15:42:57 INFO 140469236098880] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fc0faef9640>
# [12/08/2024 15:42:57 INFO 140469236098880] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [1.48550053e+01 4.99493480e-01 3.83069805e+04 1.44161992e+04
#  5.63718376e+01 2.84755554e+02 2.86010990e+01 4.57158327e-01
#  1.04523994e+02 2.84462433e+01]
# <NDArray 10 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [4.3991249e+01 5.2249998e-01 8.6659586e+04 2.4969785e+04 9.9532501e+01
#  4.9864801e+02 4.8788433e+01 2.9749998e-01 1.8536874e+02 5.0806252e+01]
# <NDArray 10 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [12/08/2024 15:42:57 INFO 140469236098880] nvidia-smi: took 0.032 seconds to run.
# [12/08/2024 15:42:57 INFO 140469236098880] nvidia-smi identified 0 GPUs.
# [12/08/2024 15:42:57 INFO 140469236098880] Number of GPUs being used: 0
# #metrics {"StartTime": 1733672577.6468842, "EndTime": 1733672577.6469219, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1600.0, "count": 1, "min": 1600, "max": 1600}, "Total Batches Seen": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2024-12-08 15:42:57.690] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 43, "num_examples": 1, "num_bytes": 67200}
# #metrics {"StartTime": 1733672577.6909873, "EndTime": 1733672577.691047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0915786743164062, "count": 1, "min": 1.0915786743164062, "max": 1.0915786743164062}}}
# #metrics {"StartTime": 1733672577.6911383, "EndTime": 1733672577.6911495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1108741760253906, "count": 1, "min": 1.1108741760253906, "max": 1.1108741760253906}}}
# #metrics {"StartTime": 1733672577.6911757, "EndTime": 1733672577.691182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.126074905395508, "count": 1, "min": 1.126074905395508, "max": 1.126074905395508}}}
# #metrics {"StartTime": 1733672577.6912115, "EndTime": 1733672577.6912189, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0945819091796876, "count": 1, "min": 1.0945819091796876, "max": 1.0945819091796876}}}
# #metrics {"StartTime": 1733672577.6912522, "EndTime": 1733672577.69126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0838146209716797, "count": 1, "min": 1.0838146209716797, "max": 1.0838146209716797}}}
# #metrics {"StartTime": 1733672577.6912966, "EndTime": 1733672577.6913056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0963032531738282, "count": 1, "min": 1.0963032531738282, "max": 1.0963032531738282}}}
# #metrics {"StartTime": 1733672577.6913366, "EndTime": 1733672577.6913445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0774141693115233, "count": 1, "min": 1.0774141693115233, "max": 1.0774141693115233}}}
# #metrics {"StartTime": 1733672577.6913738, "EndTime": 1733672577.6913831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0926148223876953, "count": 1, "min": 1.0926148223876953, "max": 1.0926148223876953}}}
# #metrics {"StartTime": 1733672577.6914165, "EndTime": 1733672577.691425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1202750396728516, "count": 1, "min": 1.1202750396728516, "max": 1.1202750396728516}}}
# #metrics {"StartTime": 1733672577.6914585, "EndTime": 1733672577.6914804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0977166748046876, "count": 1, "min": 1.0977166748046876, "max": 1.0977166748046876}}}
# #metrics {"StartTime": 1733672577.691555, "EndTime": 1733672577.6915667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0924651336669922, "count": 1, "min": 1.0924651336669922, "max": 1.0924651336669922}}}
# #metrics {"StartTime": 1733672577.6915932, "EndTime": 1733672577.6916018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.107413558959961, "count": 1, "min": 1.107413558959961, "max": 1.107413558959961}}}
# #metrics {"StartTime": 1733672577.691635, "EndTime": 1733672577.6916444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0913350677490234, "count": 1, "min": 1.0913350677490234, "max": 1.0913350677490234}}}
# #metrics {"StartTime": 1733672577.6916747, "EndTime": 1733672577.6916838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0836758422851562, "count": 1, "min": 1.0836758422851562, "max": 1.0836758422851562}}}
# #metrics {"StartTime": 1733672577.6917458, "EndTime": 1733672577.691755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1203460693359375, "count": 1, "min": 1.1203460693359375, "max": 1.1203460693359375}}}
# #metrics {"StartTime": 1733672577.691784, "EndTime": 1733672577.6917925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1040147399902345, "count": 1, "min": 1.1040147399902345, "max": 1.1040147399902345}}}
# #metrics {"StartTime": 1733672577.691823, "EndTime": 1733672577.6918323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.091817398071289, "count": 1, "min": 1.091817398071289, "max": 1.091817398071289}}}
# #metrics {"StartTime": 1733672577.6918612, "EndTime": 1733672577.6918702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1044794464111327, "count": 1, "min": 1.1044794464111327, "max": 1.1044794464111327}}}
# #metrics {"StartTime": 1733672577.6919007, "EndTime": 1733672577.6919093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0922500610351562, "count": 1, "min": 1.0922500610351562, "max": 1.0922500610351562}}}
# #metrics {"StartTime": 1733672577.691939, "EndTime": 1733672577.691947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1007720184326173, "count": 1, "min": 1.1007720184326173, "max": 1.1007720184326173}}}
# #metrics {"StartTime": 1733672577.6919758, "EndTime": 1733672577.6919844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1112955474853516, "count": 1, "min": 1.1112955474853516, "max": 1.1112955474853516}}}
# #metrics {"StartTime": 1733672577.6920156, "EndTime": 1733672577.6920245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.1011854553222655, "count": 1, "min": 1.1011854553222655, "max": 1.1011854553222655}}}
# [12/08/2024 15:42:57 INFO 140469236098880] #quality_metric: host=algo-1, epoch=0, train multiclass_cross_entropy_objective <loss>=1.0915786743164062
# [12/08/2024 15:42:57 INFO 140469236098880] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=1.0774141693115233
# [12/08/2024 15:42:57 INFO 140469236098880] Epoch 0: Loss improved. Updating best model
# [12/08/2024 15:42:57 INFO 140469236098880] Saving model for epoch: 0
# [12/08/2024 15:42:57 INFO 140469236098880] Saved checkpoint to "/tmp/tmp43_thd4z/mx-mod-0000.params"
# [12/08/2024 15:42:57 INFO 140469236098880] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1733672577.6471827, "EndTime": 1733672577.7011635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2400.0, "count": 1, "min": 2400, "max": 2400}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/08/2024 15:42:57 INFO 140469236098880] #throughput_metric: host=algo-1, train throughput=14791.396996266272 records/second
# [2024-12-08 15:42:57.731] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 29, "num_examples": 1, "num_bytes": 67200}
# #metrics {"StartTime": 1733672577.7313337, "EndTime": 1733672577.7313921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6804570770263672, "count": 1, "min": 0.6804570770263672, "max": 0.6804570770263672}}}
# #metrics {"StartTime": 1733672577.766627, "EndTime": 1733672577.7666364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.39932621002197266, "count": 1, "min": 0.39932621002197266, "max": 0.39932621002197266}}}
# #metrics {"StartTime": 1733672577.7666652, "EndTime": 1733672577.7666736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3552080535888672, "count": 1, "min": 0.3552080535888672, "max": 0.3552080535888672}}}
# #metrics {"StartTime": 1733672577.766703, "EndTime": 1733672577.7667112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9150637054443359, "count": 1, "min": 0.9150637054443359, "max": 0.9150637054443359}}}
# #metrics {"StartTime": 1733672577.76674, "EndTime": 1733672577.766749, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.052711181640625, "count": 1, "min": 1.052711181640625, "max": 1.052711181640625}}}
# #metrics {"StartTime": 1733672577.7667763, "EndTime": 1733672577.7667859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9476856994628906, "count": 1, "min": 0.9476856994628906, "max": 0.9476856994628906}}}
# #metrics {"StartTime": 1733672577.7668147, "EndTime": 1733672577.766824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8515081024169922, "count": 1, "min": 0.8515081024169922, "max": 0.8515081024169922}}}
# #metrics {"StartTime": 1733672577.7668595, "EndTime": 1733672577.7668688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.900351791381836, "count": 1, "min": 0.900351791381836, "max": 0.900351791381836}}}
# #metrics {"StartTime": 1733672577.7668993, "EndTime": 1733672577.7669091, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.828545913696289, "count": 1, "min": 0.828545913696289, "max": 0.828545913696289}}}
# #metrics {"StartTime": 1733672577.7669337, "EndTime": 1733672577.7669415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.40616695404052733, "count": 1, "min": 0.40616695404052733, "max": 0.40616695404052733}}}
# [12/08/2024 15:42:57 INFO 140469236098880] #quality_metric: host=algo-1, epoch=2, train multiclass_cross_entropy_objective <loss>=0.7168923187255859
# [12/08/2024 15:42:57 INFO 140469236098880] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=multiclass_cross_entropy_objective, value=0.32940582275390623
# [12/08/2024 15:42:57 INFO 140469236098880] Epoch 2: Loss improved. Updating best model
# [12/08/2024 15:42:57 INFO 140469236098880] Saving model for epoch: 2
# [12/08/2024 15:42:57 INFO 140469236098880] Saved checkpoint to "/tmp/tmp9_v6af6g/mx-mod-0000.params"
# [12/08/2024 15:42:57 INFO 140469236098880] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1733672577.7415254, "EndTime": 1733672577.775137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4000.0, "count": 1, "min": 4000, "max": 4000}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/08/2024 15:42:57 INFO 140469236098880] #throughput_metric: host=algo-1, train throughput=23715.055480952717 records/second
# [2024-12-08 15:42:57.801] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 25, "num_examples": 1, "num_bytes": 67200}
# #metrics {"StartTime": 1733672577.801199, "EndTime": 1733672577.8012571, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5934651947021484, "count": 1, "min": 0.5934651947021484, "max": 0.5934651947021484}}}
# #metrics {"StartTime": 1733672577.8013332, "EndTime": 1733672577.8013473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8380785369873047, "count": 1, "min": 0.8380785369873047, "max": 0.8380785369873047}}}
# #metrics {"StartTime": 1733672577.8013875, "EndTime": 1733672577.8013952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2884103393554687, "count": 1, "min": 0.2884103393554687, "max": 0.2884103393554687}}}
# #metrics {"StartTime": 1733672577.8014169, "EndTime": 1733672577.8014243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9414983367919922, "count": 1, "min": 0.9414983367919922, "max": 0.9414983367919922}}}
# #metrics {"StartTime": 1733672577.8014584, "EndTime": 1733672577.801468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.
#early_stopping_criteria_metric: host=algo-1, epoch=3, criteria=multiclass_cross_entropy_objective, value=0.21241888046264648
# [12/08/2024 15:42:57 INFO 140469236098880] Epoch 3: Loss improved. Updating best model
# [12/08/2024 15:42:57 INFO 140469236098880] Saving model for epoch: 3
# [12/08/2024 15:42:57 INFO 140469236098880] Saved checkpoint to "/tmp/tmprchj_aib/mx-mod-0000.params"
# [12/08/2024 15:42:57 INFO 140469236098880] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1733672577.7754326, "EndTime": 1733672577.8104827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4800.0, "count": 1, "min": 4800, "max": 4800}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/08/2024 15:42:57 INFO 140469236098880] #throughput_metric: host=algo-1, train throughput=22748.45900394571 records/second
# [2024-12-08 15:42:57.838] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 27, "num_examples": 1, "num_bytes": 67200}
# #metrics {"StartTime": 1733672577.8388925, "EndTime": 1733672577.8389587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5071833419799805, "count": 1, "min": 0.5071833419799805, "max": 0.5071833419799805}}}
# #metrics {"StartTime": 1733672577.8390365, "EndTime": 1733672577.8390517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7921663665771485, "count": 1, "min": 0.7921663665771485, "max": 0.7921663665771485}}}
# #metrics {"StartTime": 1733672577.8390892, "EndTime": 1733672577.8390987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.26322509765625, "count": 1, "min": 0.26322509765625, "max": 0.26322509765625}}}
# #metrics {"StartTime": 1733672577.8391318, "EndTime": 1733672577.8391411, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8987760162353515, "count": 1, "min": 0.8987760162353515, "max": 0.8987760162353515}}}
# #metrics {"StartTime": 1733672577.839176, "EndTime": 1733672577.839185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.44892444610595705, "count": 1, "min": 0.44892444610595705, "max": 0.44892444610595705}}}
# #metrics {"StartTime": 1733672577.8392177, "EndTime": 1733672577.839226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4329629135131836, "count": 1, "min": 0.4329629135131836, "max": 0.4329629135131836}}}
# #metrics {"StartTime": 1733672577.8392546, "EndTime": 1733672577.8392634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6718631744384765, "count": 1, "min": 0.6718631744384765, "max": 0.6718631744384765}}}
# #metrics {"StartTime": 1733672577.8393111, "EndTime": 1733672577.839318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9813580322265625, "count": 1, "min": 0.9813580322265625, "max": 0.9813580322265625}}}
# ...
# #metrics {"StartTime": 1733672578.1242952, "EndTime": 1733672578.124302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3047497367858887, "count": 1, "min": 0.3047497367858887, "max": 0.3047497367858887}}}
# #metrics {"StartTime": 1733672578.1243236, "EndTime": 1733672578.1243308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.211510066986084, "count": 1, "min": 0.211510066986084, "max": 0.211510066986084}}}
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, epoch=11, train multiclass_cross_entropy_objective <loss>=0.3428175735473633
# [12/08/2024 15:42:58 INFO 140469236098880] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=multiclass_cross_entropy_objective, value=0.1615359115600586
# [12/08/2024 15:42:58 INFO 140469236098880] Saving model for epoch: 11
# [12/08/2024 15:42:58 INFO 140469236098880] Saved checkpoint to "/tmp/tmpumyr39kk/mx-mod-0000.params"
# [12/08/2024 15:42:58 INFO 140469236098880] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1733672578.088201, "EndTime": 1733672578.1339874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 11200.0, "count": 1, "min": 11200, "max": 11200}, "Total Batches Seen": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/08/2024 15:42:58 INFO 140469236098880] #throughput_metric: host=algo-1, train throughput=17360.26034364119 records/second
# [2024-12-08 15:42:58.177] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 42, "num_examples": 1, "num_bytes": 67200}
# #metrics {"StartTime": 1733672578.1776135, "EndTime": 1733672578.1777298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3315421676635742, "count": 1, "min": 0.3315421676635742, "max": 0.3315421676635742}}}
# #metrics {"StartTime": 1733672578.1778479, "EndTime": 1733672578.1778998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5766716766357421, "count": 1, "min": 0.5766716766357421, "max": 0.5766716766357421}}}
# #metrics {"StartTime": 1733672578.1779485, "EndTime": 1733672578.17796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.18034595489501953, "count": 1, "min": 0.18034595489501953, "max": 0.18034595489501953}}}
# #metrics {"StartTime": 1733672578.1780338, "EndTime": 1733672578.17806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6339529037475586, "count": 1, "min": 0.6339529037475586, "max": 0.6339529037475586}}}
# #metrics {"StartTime": 1733672578.1781008, "EndTime": 1733672578.1781464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.30021158218383787, "count": 1, "min": 0.30021158218383787, "max": 0.30021158218383787}}}
# #metrics {"StartTime": 1733672578.178187, "EndTime": 1733672578.178197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.30607057571411134, "count": 1, "min": 0.30607057571411134, "max": 0.30607057571411134}}}
# #metrics {"StartTime": 1733672578.1782644, "EndTime": 1733672578.17829, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4430626678466797, "count": 1, "min": 0.4430626678466797, "max": 0.4430626678466797}}}
# #metrics {"StartTime": 1733672578.1783302, "EndTime": 1733672578.1783392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8126451110839844, "count": 1, "min": 0.8126451110839844, "max": 0.8126451110839844}}}
# #metrics {"StartTime": 1733672578.178407, "EndTime": 1733672578.1784313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2573680877685547, "count": 1, "min": 0.2573680877685547, "max": 0.2573680877685547}}}
# #metrics {"StartTime": 1733672578.1784692, "EndTime": 1733672578.1785357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.18390125274658203, "count": 1, "min": 0.18390125274658203, "max": 0.18390125274658203}}}
# #metrics {"StartTime": 1733672578.1785762, "EndTime": 1733672578.1785858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7648367309570312, "count": 1, "min": 0.7648367309570312, "max": 0.7648367309570312}}}
# #metrics {"StartTime": 1733672578.178655, "EndTime": 1733672578.178665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.37481281280517575, "count": 1, "min": 0.37481281280517575, "max": 0.37481281280517575}}}
# #metrics {"StartTime": 1733672578.1787155, "EndTime": 1733672578.1787453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3138376045227051, "count": 1, "min": 0.3138376045227051, "max": 0.3138376045227051}}}
# #metrics {"StartTime": 1733672578.1787832, "EndTime": 1733672578.1787922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.22942230224609375, "count": 1, "min": 0.22942230224609375, "max": 0.22942230224609375}}}
# #metrics {"StartTime": 1733672578.1788752, "EndTime": 1733672578.1789017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 14}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.16482969284057616, "count": 1, "min": 0.16482969284057616, "max": 0.16482969284057616}}}
# #metrics {"StartTime": 1733672578.1789396, "EndTime": 1733672578.1789482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 15}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6094594955444336, "count": 1, "min": 0.6094594955444336, "max": 0.6094594955444336}}}
# #metrics {"StartTime": 1733672578.1790183, "EndTime": 1733672578.1790283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 16}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.9673564147949218, "count": 1, "min": 0.9673564147949218, "max": 0.9673564147949218}}}
# #metrics {"StartTime": 1733672578.179059, "EndTime": 1733672578.179075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 17}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6674708557128907, "count": 1, "min": 0.6674708557128907, "max": 0.6674708557128907}}}
# #metrics {"StartTime": 1733672578.1791356, "EndTime": 1733672578.1791449, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 18}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3233852767944336, "count": 1, "min": 0.3233852767944336, "max": 0.3233852767944336}}}
# #metrics {"StartTime": 1733672578.1792257, "EndTime": 1733672578.179236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 19}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3917348861694336, "count": 1, "min": 0.3917348861694336, "max": 0.3917348861694336}}}
# #metrics {"StartTime": 1733672578.1792881, "EndTime": 1733672578.1792977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.28127389907836914, "count": 1, "min": 0.28127389907836914, "max": 0.28127389907836914}}}
# #metrics {"StartTime": 1733672578.1793633, "EndTime": 1733672578.1793733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2075008773803711, "count": 1, "min": 0.2075008773803711, "max": 0.2075008773803711}}}
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, epoch=12, train multiclass_cross_entropy_objective <loss>=0.3315421676635742
# [12/08/2024 15:42:58 INFO 140469236098880] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=multiclass_cross_entropy_objective, value=0.16482969284057616
# [12/08/2024 15:42:58 INFO 140469236098880] Saving model for epoch: 12
# [12/08/2024 15:42:58 INFO 140469236098880] Saved checkpoint to "/tmp/tmp2itce4pz/mx-mod-0000.params"
# [12/08/2024 15:42:58 INFO 140469236098880] Early stop condition met. Stopping training.
# [12/08/2024 15:42:58 INFO 140469236098880] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1733672578.1344228, "EndTime": 1733672578.1914804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/08/2024 15:42:58 INFO 140469236098880] #throughput_metric: host=algo-1, train throughput=13987.832401629128 records/second
# [12/08/2024 15:42:58 WARNING 140469236098880] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/08/2024 15:42:58 WARNING 140469236098880] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2024-12-08 15:42:58.195] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 30, "duration": 2, "num_examples": 1, "num_bytes": 67200}
# [2024-12-08 15:42:58.209] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 9, "num_examples": 1, "num_bytes": 67200}
# /opt/amazon/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from nested sequences exceeding the maximum number of dimensions of 32 is deprecated. If you mean to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('multiclass_cross_entropy_objective', 0.15128823280334472)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('multiclass_accuracy', 0.9325)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('dcg', 0.9750877380371094)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('macro_recall', 0.52658206)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('macro_precision', nan)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('macro_f_1.000', 0.5613622)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('multiclass_balanced_accuracy', 0.5265820565090639)
# [12/08/2024 15:42:58 INFO 140469236098880] #train_score (algo-1) : ('multiclass_log_loss', 0.6324364307922596)
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train multiclass_cross_entropy_objective <loss>=0.15128823280334472
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train multiclass_accuracy <score>=0.9325
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train multiclass_top_k_accuracy_3 <score>=1.0
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train dcg <score>=0.9750877380371094
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train macro_recall <score>=0.5265820622444153
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train macro_precision <score>=nan
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train macro_f_1.000 <score>=0.5613622069358826
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train multiclass_balanced_accuracy <score>=0.5265820565090639
# [12/08/2024 15:42:58 INFO 140469236098880] #quality_metric: host=algo-1, train multiclass_log_loss <score>=0.6324364307922596
# [12/08/2024 15:42:58 INFO 140469236098880] Best model found for hyperparameters: {"optimizer": "rmsprop", "learning_rate": 0.11741784914926481, "l1": 0.0011191600215386343, "wd": 0.0026286758952262894, "lr_scheduler_step": 37, "lr_scheduler_factor": 0.9957325431879323, "lr_scheduler_minimum_lr": 0.00011956244022128876}
# [12/08/2024 15:42:58 INFO 140469236098880] Saved checkpoint to "/tmp/tmplxk1ihtw/mx-mod-0000.params"
# [12/08/2024 15:42:58 INFO 140469236098880] Test data is not provided.
# #metrics {"StartTime": 1733672577.4890292, "EndTime": 1733672578.2398083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 155.70855140686035, "count": 1, "min": 155.70855140686035, "max": 155.70855140686035}, "epochs": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "check_early_stopping.time": {"sum": 9.435892105102539, "count": 13, "min": 0.16188621520996094, "max": 1.711130142211914}, "update.time": {"sum": 502.1958351135254, "count": 13, "min": 31.145334243774414, "max": 53.88474464416504}, "finalize.time": {"sum": 35.02821922302246, "count": 1, "min": 35.02821922302246, "max": 35.02821922302246}, "setuptime": {"sum": 2.023458480834961, "count": 1, "min": 2.023458480834961, "max": 2.023458480834961}, "totaltime": {"sum": 861.4957332611084, "count": 1, "min": 861.4957332611084, "max": 861.4957332611084}}}
#
# 2024-12-08 15:43:15 Completed - Training job completed
# Training seconds: 145
# Billable seconds: 145

# %%
# Desplegar el modelo en un endpoint
linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: linear-learner-2024-12-08-15-44-17-941
# INFO:sagemaker:Creating endpoint-config with name linear-learner-2024-12-08-15-44-17-941
# INFO:sagemaker:Creating endpoint with name linear-learner-2024-12-08-15-44-17-941
# ------------------!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       5 for i in range(len(X_test)):
#       6     payload = ','.join(map(str, X_test[i]))
# ----> 7     response = linear_predictor.predict(payload)
#       8     predicted_label = np.argmax(response['predictions'][0]['score'])
#       9     predictions.append(predicted_label)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/base_predictor.py:199, in Predictor.predict(self, data, initial_args, target_model, target_variant, inference_id, custom_attributes, component_name)
#     158 """Return the inference from the specified endpoint.
#     159
#     160 Args:
#    (...)
#     196         as is.
#     197 """
#     198 # [TODO]: clean up component_name in _create_request_args
# --> 199 request_args = self._create_request_args(
#     200     data=data,
#     201     initial_args=initial_args,
#     202     target_model=target_model,
#     203     target_variant=target_variant,
#     204     inference_id=inference_id,
#     205     custom_attributes=custom_attributes,
#     206 )
#     208 inference_component_name = component_name or self._get_component_name()
#     209 if inference_component_name:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/base_predictor.py:286, in Predictor._create_request_args(self, data, initial_args, target_model, target_variant, inference_id, custom_attributes, target_container_hostname)
#     280 if custom_attributes:
#     281     args["CustomAttributes"] = custom_attributes
#     283 data = (
#     284     jumpstart_serialized_data
#     285     if isinstance(data, JumpStartSerializablePayload) and jumpstart_serialized_data
# --> 286     else self.serializer.serialize(data)
#     287 )
#     288 if self._get_component_name():
#     289     args["InferenceComponentName"] = self.component_name
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/amazon/common.py:51, in RecordSerializer.serialize(self, data)
#      42 def serialize(self, data):
#      43     """Serialize a NumPy array into a buffer containing RecordIO records.
#      44
#      45     Args:
#    (...)
#      49         io.BytesIO: A buffer containing the data serialized as records.
#      50     """
# ---> 51     if len(data.shape) == 1:
#      52         data = data.reshape(1, data.shape[0])
#      54     if len(data.shape) != 2:
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
# Imprimir el nombre del endpoint
print(f"Endpoint name: {linear_predictor.endpoint_name}")
# Out:
# Endpoint name: linear-learner-2024-12-08-15-44-17-941

# %%
import boto3

# Crear cliente de SageMaker
sagemaker_client = boto3.client('sagemaker')

# Listar todos los endpoints
endpoints = sagemaker_client.list_endpoints()

# Imprimir detalles de los endpoints
for endpoint in endpoints['Endpoints']:
    print(f"Nombre: {endpoint['EndpointName']}")
    print(f"Estado: {endpoint['EndpointStatus']}")
    print(f"Creado: {endpoint['CreationTime']}")
    print("-------------------")
# Out:
# Nombre: linear-learner-2024-12-08-15-44-17-941
# Estado: InService
# Creado: 2024-12-08 15:44:19.242000+00:00
# -------------------

# %%
import boto3
import csv
import io

# Configuración
runtime = boto3.client('sagemaker-runtime')
endpoint_name = 'linear-learner-2024-12-08-15-44-17-941'

# Datos de prueba
test_sample = [30, 50090, 20000, 50, 400, 70, 1, 10, 30, 5]

# Convertir a CSV
buf = io.StringIO()
writer = csv.writer(buf)
writer.writerow(test_sample)
payload = buf.getvalue()

# Realizar predicción
try:
    response = runtime.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType='text/csv',
        Body=payload
    )
    result = response['Body'].read().decode()
    print(f"Input: {test_sample}")
    print(f"Predicción: {result}")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Input: [30, 50090, 20000, 50, 400, 70, 1, 10, 30, 5]
# Predicción: {"predictions": [{"score": [1.000000013351432e-10, 1.0, 1.000000013351432e-10], "predicted_label": 1}]}

# %%
import boto3
sagemaker_client = boto3.client('sagemaker')
response = sagemaker_client.list_endpoints()
for endpoint in response['Endpoints']:
    print(endpoint['EndpointName'], endpoint['EndpointStatus'])
# Out:
# linear-learner-2024-12-08-15-44-17-941 InService

# %%
response = sagemaker_client.describe_endpoint(EndpointName='linear-learner-2024-12-08-15-44-17-941')
print(response['EndpointStatus'])
# Out:
# InService

# %%
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (200, 10)
# y_test shape: (200,)

# %%
# Evaluación del modelo con el conjunto de prueba
import json
import boto3
from sklearn.metrics import classification_report, f1_score, accuracy_score
import numpy as np

# Convertir el conjunto de prueba a CSV para enviar al endpoint
def get_predictions_from_endpoint(endpoint_name, X_test):
    predictions = []
    runtime = boto3.client('sagemaker-runtime')
    
    for row in X_test:
        buf = io.StringIO()
        writer = csv.writer(buf)
        writer.writerow(row)
        payload = buf.getvalue()
        
        response = runtime.invoke_endpoint(
            EndpointName=endpoint_name,
            ContentType='text/csv',
            Body=payload
        )
        result = json.loads(response['Body'].read().decode())
        # Suponiendo que 'predicted_label' contiene la clase predicha
        predictions.append(int(result['predictions'][0]['predicted_label']))
    
    return predictions

# Obtener las predicciones del endpoint
y_pred = get_predictions_from_endpoint(endpoint_name, X_test)

# Calcular métricas de evaluación
print("Reporte de clasificación:")
print(classification_report(y_test, y_pred, target_names=list(customer_segment_map.values())))

# F1-score general
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1-score (ponderado): {f1}")

# Precisión global
accuracy = accuracy_score(y_test, y_pred)
print(f"Precisión: {accuracy}")
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   high_value       1.00      0.48      0.65        25
#    low_value       0.00      0.00      0.00         2
# medium_value       0.92      1.00      0.96       173
#
#     accuracy                           0.93       200
#    macro avg       0.64      0.49      0.54       200
# weighted avg       0.92      0.93      0.91       200
#
# F1-score (ponderado): 0.9101392528262334
# Precisión: 0.925
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
